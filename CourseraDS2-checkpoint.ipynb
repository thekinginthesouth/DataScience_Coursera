# %%
pip install yfinance
# Out:
# ...
#
# ...

# %%
import yfinance as yf

# Download Tesla stock data
tesla_data = yf.download('TSLA', start='2020-01-01', end='2023-01-01')

# Reset the index
tesla_data.reset_index(inplace=True)

# Display the first five rows of the dataframe
print(tesla_data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
#         Date       Open       High        Low      Close  Adj Close     Volume
# 0 2020-01-02  28.299999  28.713333  28.114000  28.684000  28.684000  142981500
# 1 2020-01-03  29.366667  30.266666  29.128000  29.534000  29.534000  266677500
# 2 2020-01-06  29.364668  30.104000  29.333332  30.102667  30.102667  151995000
# 3 2020-01-07  30.760000  31.441999  30.224001  31.270666  31.270666  268231500
# 4 2020-01-08  31.580000  33.232666  31.215334  32.809334  32.809334  467164500

# %%
pip install requests beautifulsoup4 pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Define the URL from which to scrape Tesla revenue data
url = "https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue"

# Send a request to fetch the webpage content
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# Find all the tables on the page
tables = soup.find_all('table', {'class': 'historical_data_table'})

# Check the number of tables found
print(f"Number of tables found: {len(tables)}")

# If at least one table is found, proceed
if len(tables) > 0:
    # Select the first table (if only one exists or if this is the correct one)
    table = tables[0]

    # Extract the data into a list
    rows = table.find_all('tr')

    # Create a list to hold the revenue data
    revenue_data = []

    # Loop through the rows to get data
    for row in rows[1:]:  # Skip the header
        cols = row.find_all('td')
        date = cols[0].text.strip()
        revenue = cols[1].text.strip().replace('$', '').replace(',', '')  # Clean the revenue format
        revenue_data.append([date, revenue])

    # Convert the data into a pandas DataFrame
    tesla_revenue = pd.DataFrame(revenue_data, columns=['Date', 'Revenue'])

    # Drop any rows with missing or invalid data
    tesla_revenue = tesla_revenue[tesla_revenue['Revenue'] != '']

    # Display the last five rows of the dataframe
    print(tesla_revenue.tail())
else:
    print("No tables found with the specified class.")
# Out:
# Number of tables found: 0
# No tables found with the specified class.

# %%
import yfinance as yf

# Download GameStop stock data
gme_data = yf.download('GME', start='2020-01-01', end='2023-01-01')

# Reset the index
gme_data.reset_index(inplace=True)

# Display the first five rows of the dataframe
print(gme_data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
#         Date    Open    High     Low   Close  Adj Close    Volume
# 0 2020-01-02  1.5350  1.6175  1.5175  1.5775     1.5775  17814400
# 1 2020-01-03  1.5525  1.5625  1.4600  1.4700     1.4700  14175600
# 2 2020-01-06  1.4500  1.4775  1.4000  1.4625     1.4625  13579200
# 3 2020-01-07  1.4425  1.4575  1.3600  1.3800     1.3800  20912000
# 4 2020-01-08  1.3725  1.4625  1.3525  1.4300     1.4300  22517600

# %%
pip install requests beautifulsoup4 pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Define the URL from which to scrape GameStop revenue data
url = "https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue"

# Send a request to fetch the webpage content
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# Find the revenue table on the page
table = soup.find_all('table', {'class': 'historical_data_table'})

# Check the number of tables found
print(f"Number of tables found: {len(table)}")

# Ensure that the table is found
if len(table) > 0:
    # Select the first table (if only one exists or if this is the correct one)
    table = table[0]

    # Extract the data into a list
    rows = table.find_all('tr')

    # Create a list to hold the revenue data
    revenue_data = []

    # Loop through the rows to get data
    for row in rows[1:]:  # Skip the header
        cols = row.find_all('td')
        date = cols[0].text.strip()
        revenue = cols[1].text.strip().replace('$', '').replace(',', '')  # Clean the revenue format
        revenue_data.append([date, revenue])

    # Convert the data into a pandas DataFrame
    gme_revenue = pd.DataFrame(revenue_data, columns=['Date', 'Revenue'])

    # Drop any rows with missing or invalid data
    gme_revenue = gme_revenue[gme_revenue['Revenue'] != '']

    # Display the last five rows of the dataframe
    print(gme_revenue.tail())
else:
    print("No tables found with the specified class.")
# Out:
# Number of tables found: 0
# No tables found with the specified class.

# %%
pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.5 MB 1.9 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.0/7.5 MB 2.3 MB/s eta 0:00:03
#    --------- ------------------------------ 1.8/7.5 MB 2.6 MB/s eta 0:00:03
#    ------------ --------------------------- 2.4/7.5 MB 2.7 MB/s eta 0:00:02
#    --------------- ------------------------ 2.9/7.5 MB 2.7 MB/s eta 0:00:02
#    ------------------- -------------------- 3.7/7.5 MB 2.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.2/7.5 MB 2.8 MB/s eta 0:00:02
#    -------------------------- ------------- 5.0/7.5 MB 2.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.5/7.5 MB 2.9 MB/s eta 0:00:01
#    --------------------------------- ------ 6.3/7.5 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------- -- 7.1/7.5 MB 3.0 MB/s eta 0:00:01
# ...

# %%
import matplotlib.pyplot as plt
import yfinance as yf

def make_graph(data, title):
    # Plot the data
    plt.figure(figsize=(10, 6))
    plt.plot(data['Date'], data['Close'], label='Closing Price')
    plt.xlabel('Date')
    plt.ylabel('Price (USD)')
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.tight_layout()  # Adjust layout to prevent clipping of labels
    plt.show()

# Download Tesla stock data
tesla_data = yf.download('TSLA', start='2020-01-01', end='2023-01-01')

# Reset the index
tesla_data.reset_index(inplace=True)

# Plot the graph with the title
make_graph(tesla_data, 'Tesla Stock Closing Prices')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
import matplotlib.pyplot as plt
import yfinance as yf

def make_graph(data, title):
    # Plot the data
    plt.figure(figsize=(10, 6))
    plt.plot(data['Date'], data['Close'], label='Closing Price')
    plt.xlabel('Date')
    plt.ylabel('Price (USD)')
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.tight_layout()  # Adjust layout to prevent clipping of labels
    plt.show()

# Download GameStop stock data
gme_data = yf.download('GME', start='2020-01-01', end='2023-01-01')

# Reset the index
gme_data.reset_index(inplace=True)

# Plot the graph with the title
make_graph(gme_data, 'GameStop Stock Closing Prices')
# Out:
# [*********************100%***********************]  1 of 1 completed
